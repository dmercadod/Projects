# %% [markdown]
# <div class="text-cell-section-header">
# <h1 style="text-align: center;"><strong>PROGRAMACI&Oacute;N PARA EL AN&Aacute;LISIS DE DATOS</strong></h1>
# </div>
# <h1 style="text-align: center;"><strong>Tarea 1 - Principios b&aacute;sicos de programaci&oacute;n cient&iacute;fica.</strong></h1>
# <h1 style="text-align: center;"><strong>PRESENTADO POR: DARWIN MERCADO</strong></h1>
# <h1 style="text-align: center;"><strong>GRUPO 203008069_3</strong></h1>
# <h1 style="text-align: center;"><strong>PRESENTADO A FELIPE ALEXANDER PIPICANO GUZMAN</strong></h1>
# <h1 style="text-align: center;"><strong>Universidad Nacional Abierta y a Distancia &ndash; UNAD</strong></h1>
# <h1 style="text-align: center;"><strong>18 de septiembre del 2023</strong></h1>

# %% [markdown]
# # **PRESENTACION DEL EJERCICIO**
#
# EJERCICIO 3: Gráficos cientificos
#
# ## Gráfico 1: Esta visualización debe cumplir con las siguientes condiciones:
#
# • Mostrar los puntos de dispersión del emparejamiento las
# siguientes listas:
#
# x= [13,14,15,16,17,18] , y= [16,24,45,57,75,102]
# • Mostrar la función lineal $𝒇(𝒙) = 𝟏𝟕𝒙 − 𝟐𝟏𝟎. 𝟑𝟑𝟑𝟑$ en el dominio
# [13,18].
#
# • Mostrar la función exponencial $𝒈(𝒙) = 𝟎. 𝟏𝟒𝟓𝟐 𝒆
# (𝟎.𝟑𝟔𝟗𝒙)$ en el
# dominio [13,18].
#
# • Mostrar la función logarítmica $𝒉(𝒙) = 𝟐𝟓𝟗. 𝟒𝟗 𝒍𝒏(𝒙) − 𝟔𝟓𝟔. 𝟒𝟔$ en el
# dominio [13,18].
#
# • Los objetos mostrados deben tener colores diferentes.
#
# • La línea de la función logarítmica debe ser punteada.
#
# • En los ejes deben visualizarse los números.
#
# • Asigne un nombre (label) a cada objeto e imprima la legenda
# que los identifique en la gráfica.
#
# • Asigne nombres a los ejes de la gráfica.
#
# • Asigne un título a la gráfica.
#
# • Tenga en cuenta que los nombres que decida utilizar le serán de
# ayuda para presentar las conclusiones que usted obtenga del
# ejercicio.
#
# ## Gráfico 2: Construya los códigos necesarios para:
# • Generar 4 listas aleatorias de 700 muestras (revise la
# documentación de numpy.random):
# - x1 con distribución normal de media 5 y desviación
# estándar 0.1.
# - y1 con distribución normal de media 7 y desviación
# estándar 0.1.
# - x2 con distribución uniforme entre el valor mínimo de x1 y
# el valor máximo de x1.
# - y2 con distribución uniforme entre el valor mínimo de y1 y
# el valor máximo de y1.
#
# • Graficar en un mismo plot nubes de dispersión de los pares de
# puntos que se forman con (x1, y1) y (x2, y2).
# • La nube de puntos (x2, y2) debe visualizarse sobre la nube de
# (x1, y1).
#
# • Anexe los títulos y legendas necesarios para poder citar y
# explicar realizar el análisis del gráfico obtenido y las
# conclusiones.
#
# ## Gráficos 3: Genere las siguientes dos visualizaciones que se proponena continuación:
#
# • Cargue en la variable df1 el conjunto de datos que se presentan
# en el archivo Excel, Anexo 1 - Base de Datos Excel.xlsx, que se
# encuentra en la carpeta de la Tarea 1 - Fundamentos de
# programación científica con Python.
#
# • En una misma gráfica presente 2 histogramas de las variables
# Tiempo motor ON y Tiempo en Movimiento, respectivamente.
# Deben ser lo suficientemente transparentes, para poder ver
# ambas al tiempo. (Revise la documentación de la función
# matplotlib.pyplot.hist).
#
# • En otra gráfica, genere el gráfico de dispersión que se obtiene
# de emparejar los valores de Tiempo motor ON y Tiempo en
# Movimiento.
#
# • Anexe los títulos y legendas necesarios en ambos gráficos para
# poder citar y explicar el análisis de los gráficos obtenidos y las
# conclusiones.

# %% [markdown]
# # **Revisión teórica**
#
# ## - Graficos de dispersión:
#
# Este tipo de gráfico representan dos variables como puntos en un plano y se puede ver su relación entre ellas. Adicional a esto son gráficos óptimos para representar grupos y conglomerados. Se puede utilizar la función .scatter de la librería matplotlib.pyplot para obtener un gráfico de dispersión.(Thakur, 2016)
#
# ## - Histogramas
#
# Los histogramas son gráficos que se utilizan para representar de manera efectiva la distribución de una variable. Generalmente se toma el rango de valores y se dividen en intervalos de tamaño igual, y la elevación de cada intervalo corresponde a la frecuencia de valores dentro de ese intervalo. (Thakur, 2016)
#
# ## - Gráfico de barras
#
# El gráfico de barras es utilizado para mostrar datos agrupados a partir de barras rectanguales, que pueden ser verticales o horizontales, y la elevación o longitud de estas corresponden a sus valores.(Thakur, 2016)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Gráfico 1

# %%
x = [13,14,15,16,17,18]
y = [16,24,45,57,75,102]

# %%
def fx(x): ##funcion lineal
    return 17*x - 210.3333

def gx(x): ## funcion exponencial
    return 0.1452 * np.exp (0.369*x)

def hx(x): ## funcion logaritmica
    return 259.49*np.log(x) - 656.46

##Dominio solicitado de [13,18]
dominio = np.linspace(13,18,100)
lineal = fx(dominio)
exponencial = gx(dominio)
logaritmica=hx(dominio)

##Grafíco de puntos de dispersión
plt.scatter(x, y,label = "Puntos de dispersion", color='green')

## Gráfico de función líneal
plt.plot(dominio, lineal, label='f(x) = 17x - 210.3333', color='yellow')

## Gráfico de función exponencial
plt.plot(dominio,exponencial, label = "g(x) = 0.1452*exp^(0.369*x)",color = "red" )

## Gráfico de función logaritmica
plt.scatter(dominio,logaritmica, label = "h(x) 259.49ln(x)-656.46", color = "pink")

## Agregamos la legenda en el gráfico
plt.legend()

## Se da el nombre al eje x y y
plt.xlabel("x")
plt.ylabel("y")

## Se agrega el titulo a la gráfica
plt.title("Grafico 1")

## Se muesta el grafico
plt.show()

# %% [markdown]
# # Gráfico 2

# %%
## Generar 4 listas aleatorias de 700 muestras (revise la documentación de numpy.random):
media=5
desve= 0.1
x1= np.random.normal(loc=media,scale=desve, size = 700)
media2=7
desvie2=0.1
y1= np.random.normal(loc=media2,scale=desvie2, size = 700)
x2=np.random.uniform(low=(min(x1)),high=(max(x1)), size= 700)
y2=np.random.uniform(low=(min(y1)),high=(max(y1)), size = 700)

# %%
##Graficar en un mismo plot nubes de dispersión de los pares de puntos que se forman con (x1, y1) y (x2, y2)
plt.scatter(x1,y1, label = "Distribución normal de (x1,y1)", s= 30,color ="red")
plt.scatter(x2,y2, label = "Distribución uniformen (x2,y2)", s=30 , color = "yellow")
plt.title("Gráfico 2")
plt.legend()
plt.show()

# %%
##La nube de puntos (x2, y2) debe visualizarse sobre la nube de (x1, y1).
plt.scatter(x1,y1,label = "x1,y1", color = "yellow")
plt.scatter(x2,y2,label = "x2,y2", color ="red")
plt.title("Gráfico 2")
plt.legend()
plt.show()

# %% [markdown]
# # Gráfico 3

# %%
## Cargamos el archivo excel
df1 = pd.read_excel("Anexo 1 - Base de Datos EXCEL.xlsx",sheet_name = 1, header= 3, index_col = 0)

# %%
df1
# Out:
#          Empresa Turno  Día de la semana Experiencia del conductor  \
# Servicio
# 1            TAC     D                 5              Principiante
# 2            TAD     N                 4              Principiante
# 3            TAB     N                 4                   Experto
# 4            TAB     D                 2                Intermedio
# 5            TAC     N                 7              Principiante
# ...          ...   ...               ...                       ...
# 2196         TAB     D                 3                   Experto
# 2197         TAB     N                 6                Intermedio
# 2198         TAB     D                 3              Principiante
# 2199         TAD     D                 7                Intermedio
# 2200         TAD     D                 3                Intermedio
#
#           Formación del Paramédico Nivel del Paramédico  \
# Servicio
# 1                                4                    I
# ...

# %%
## Presentación del gráfico con los histogramas de las dos variables Tiempo motor ON y Tiempo en movimiento.
plt.hist(df1["Tiempo motor ON (h)"], bins = 20, alpha=0.1, color = "Red", label= "Tiempo motor ON (h)")
plt.hist(df1["Tiempo en Movimiento (h)"], bins = 20, alpha=0.1, color = "y",label= "Tiempo en movimiento (h)")
plt.ylabel("Freq")
plt.xlabel("Tiempo")
plt.legend()
plt.grid(True)
plt.show()

# %%
## Generación de gráfico de dispersión.
plt.scatter(df1["Tiempo motor ON (h)"],df1["Tiempo en Movimiento (h)"], alpha = 0.5, color = "red")
plt.xlabel("Tiempo motor ON (h)")
plt.ylabel("Tiempo en Movimiento (h)")
plt.title("Tiempo motor ON vs Tiempo en Movimiento (h)")
plt.grid(True)
plt.show()

# %% [markdown]
# # **Analisis de resultado**
#
# # **Gráfico 1:**
# - En este gráfico podemos observar las líneas de las diferentes funciones, las cuales tienen como fin poder crear una línea que se ajuste a los puntos de dispersión en la gráfica que fueron planteados en el momento inicial con el conjunto de datos de "x" y "y".
#
# - Cuando se analiza de manera visual este gráfico se observa que la grafíca de la función exponencial dada $g(x) = 0.1452*exp^(0.369*x)$ se apróxima más a los puntos de dispersión graficados, por lo tanto se puede concluir que para este conjunto de datos esta función es la que mejor se ajusta.
#
# # **Gráfico 2**
# ##  **Graficar en un mismo plot nubes de dispersión de los pares de puntos que se forman con (x1, y1) y (x2, y2).**
#
# - En el grafico de puntos de distribución normal (x1,y1) podemos observar que se está cumpliendo con esta caracteristica, observando la mayor concentración de puntos en el punto medio de esta distribución, dandonos así un punto de probabilidad en el numero 5.0 que es la media dada en el eje **x** y en el eje **y** de 7.0 con una desviación estandar de +/- 1 que se le dio al momento de crear los 700 puntos aleatorios. Hacía los lados distales vemos una disminución de concentración, por otro lado se puede observar que en la distribución uniforme (x2,y2) vemos que hay una correcta distribución sobre todo el plano carteciano, cumpliendo de manera eficiente su caracteristica principal y poder ve que hay varias probabilidades observadas en el espacio que se tiene.
#
# # **La nube de puntos (x2, y2) debe visualizarse sobre la nube de (x1, y1).**
#
# - En este segundo gráfico se observa el mismo comportamiento, los datos de (x1,y1) siguen estando en su distribución normal dentro de la media de 5.0 en eje **x** y 7.0 en el eje **y** y desviación estandar de 0.1, teniendo así que la mayor probabilidad esta entre el valor de 5.0 +/- 0.1 para el eje **x** y en el eje **y** es de 7.0 +/-0.1 que ocurran estos puntos, por lo tanto cumple con su carácteristica y en el gráfico de (x2,y2) observamos la misma distribución uniforme sobre el gráfico observando su probabilidad de que el punto se grafíque en todo el plano carteciano de manera uniforme.
#
# # **Gráfico 3**
# # **En una misma gráfica presente 2 histogramas de las variables Tiempo motor ON y Tiempo en Movimiento, respectivamente.**
#
# En este gráfico se puede observar que a mayor tiempo este el motor encendido hay mayor movimiento, adicional a esto se puede observar que entre la hora 2.5 y 3.5 hay una pequeña intersección de los histogramas, la cual se observa una distribución normal en ese punto, donde la mayor frecuencia de datos es en las 3.0 horas. En el gráfico del tiempo de movimiento también se observa una distribución normal de los datos  teniendo su centro en 2.9 horas y con una desviación estandar de aproximadamente 0.5 horas. Se puede observar que en la hora numero 2.8 aproximadamente hay un mayor pico de frecuencia de los datos de tiempo en movimiento. En el gráfico del tiempo del motor encendido también podemos observar una distribución normal, por lo tanto se puede predecir que entre las horas 3.2 y 4.8, hay una concentración mayoritaria de los datos de encendido.
#
# También se puede analizar que este tipo de vehiculos mantienen a veces mas tiempo encendidos que el movimiento que hacen, dado que por ser transporte de emergencia deben de esperar a que se les indique en que momento realizar un servicio, por lo tanto mantienen los vehiculos preparados en caso de alguna emergencia.
#
# # **En otra gráfica, genere el gráfico de dispersión que se obtiene de emparejar los valores de Tiempo motor ON y Tiempo en Movimiento.**
#
# Se puede observar en este gráfico de dispersión claramente lo que se indico en el analisis anterior, donde a mayor tiempo de motor encendido hay mayor movimiento, adicional a esto se puede observar que entre las horas 2.25 y la 3.25 del tiempo de movimiento se puede observar una mayor concentración de los puntos gráficados. También se puede corroborar que al ser un servicio de emergencia y que esperan por llamado de que los necesiten, se nota claramente que mantienen mas tiempo con el motor encendido vs el tiempo en movimiento, con esto poder estar preparados en caso de que los necesiten.

# %% [markdown]
# # **Concluciones**
#
# - De este ejercicio se puede concluir que existes varios metodos o funciones que nos pueden dar la mejor intersección de unos puntos de dispersión y asi poder tomar la mejor decisión en el futuro, adicional a esto se pudo aprender a como implementar graficos cientificos de funciones.
#
# - En el gráfico números dos se pudo reforzar los conocimientos de distribución normal y uniforme, teniendo como punto de partida poder conocer cuales eran los datos datos por el tutor y saber entener como plantear estos puntos, también se pudo visualizar correctamente como se ve un gráfico de distribución normal de puntos aleatorios y de distribución uniforme.
#
# - En el gráfico número tres se pudo concluir que al momento de los recorridos realizados por cada conductor de ambulancia, la variable tiempo de motor encendido era esencial para entender que ellos al ser un servicio de emergencias debian de mantener el motor mas tiempo encendido de lo que duraban en tiempo en movimiento por sus traslados, esperas, entre otros.

# %% [markdown]
# # **Referencias**
#
# - Álvarez, C. (2020). Introducción al Jupyter Notebook y aplicaciones básicas. https://repository.unad.edu.co/handle/10596/35681
#
# - Thakur, A. (2016). Python: Real-World Data Science. Packt Publishing. https://bibliotecavirtual.unad.edu.co/login?url=https://search.ebscohost.com/login.aspx?direct=true&db=nlebk&AN=1250754&lang=es&site=ehost-live&ebv=EB&ppid=pp_199
#
# - Alberto Boschetti, & Luca Massaron. (2016). Python Data Science Essentials - Second Edition (Vol. 0002). Packt Publishing.
#
# - Kane, F. (2017). Hands-On Data Science and Python Machine Learning. Packt Publishing. https://bibliotecavirtual.unad.edu.co/login?url=https://search.ebscohost.com/login.aspx?direct=true&db=nlebk&AN=1566405&lang=es&site=ehost-live&ebv=EB&ppid=pp_20
